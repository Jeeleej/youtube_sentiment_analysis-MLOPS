# %%
# !pip install mlflow boto3 awscli optuna xgboost
# Out:
# Requirement already satisfied: mlflow in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (2.17.0)
# Requirement already satisfied: boto3 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (1.43.46)
# Requirement already satisfied: awscli in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (1.45.46)
# Requirement already satisfied: optuna in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (4.9.0)
# Requirement already satisfied: xgboost in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (3.2.0)
# Requirement already satisfied: mlflow-skinny==2.17.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (2.17.0)
# Requirement already satisfied: Flask<4 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (1.18.5)
# Requirement already satisfied: docker<8,>=4.0.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (7.2.0)
# Requirement already satisfied: graphene<4 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (3.10.2)
# Requirement already satisfied: matplotlib<4 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (3.9.2)
# Requirement already satisfied: numpy<3 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (2.1.2)
# Requirement already satisfied: pandas<3 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<18,>=4.0.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (17.0.0)
# Requirement already satisfied: scikit-learn<2 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (1.9.0)
# Requirement already satisfied: scipy<2 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (1.17.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (2.0.51)
# Requirement already satisfied: Jinja2<4,>=3.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (3.1.6)
# Requirement already satisfied: waitress<4 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (8.4.2)
# Requirement already satisfied: cloudpickle<4 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (0.120.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (3.1.50)
# Requirement already satisfied: importlib-metadata!=4.7.0,<9,>=3.7.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (8.9.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (1.43.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (1.43.0)
# Requirement already satisfied: packaging<25 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (5.29.6)
# Requirement already satisfied: pyyaml<7,>=5.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (2.34.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (0.5.5)
# Requirement already satisfied: Mako in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.12)
# Requirement already satisfied: typing-extensions>=4.12 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.16.0)
# Requirement already satisfied: colorama in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from click<9,>=7.0->mlflow-skinny==2.17.0->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (2.55.2)
# Requirement already satisfied: urllib3<3,>=1.26 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (2.7.0)
# Requirement already satisfied: pywin32>=304 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from docker<8,>=4.0.0->mlflow) (312)
# Requirement already satisfied: Werkzeug>=3.0.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from Flask<4->mlflow) (3.1.8)
# Requirement already satisfied: itsdangerous>=2.1.2 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.17.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.17.0->mlflow) (5.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (49.0.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from graphene<4->mlflow) (3.2.11)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.17.0->mlflow) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from Jinja2<4,>=3.0->mlflow) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from matplotlib<4->mlflow) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from matplotlib<4->mlflow) (1.5.0)
# Requirement already satisfied: pillow>=8 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from matplotlib<4->mlflow) (12.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.64b0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.17.0->mlflow) (0.64b0)
# Requirement already satisfied: pytz>=2020.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from pandas<3->mlflow) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from pandas<3->mlflow) (2026.3)
# Requirement already satisfied: six>=1.5 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (2026.6.17)
# Requirement already satisfied: joblib>=1.4.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: narwhals>=2.0.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from scikit-learn<2->mlflow) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.5.3)
# Requirement already satisfied: botocore<1.44.0,>=1.43.46 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from boto3) (1.43.46)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from boto3) (0.19.1)
# Requirement already satisfied: docutils<=0.19,>=0.18.1 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from awscli) (0.19)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from awscli) (4.7.2)
# Requirement already satisfied: pyasn1>=0.1.3 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.4)
# Requirement already satisfied: colorlog in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from optuna) (6.10.1)
# Requirement already satisfied: tqdm in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from optuna) (4.68.4)
# Requirement already satisfied: cffi>=2.0.0 in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (2.1.0)
# Requirement already satisfied: pycparser in V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (3.0)
# WARNING: Ignoring invalid distribution ~otocore (V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otocore (V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otocore (V:\YouTube-Sentiment-Insights\.venv\Lib\site-packages)

# %%
# !aws configure
# Out:
# ^C

# %%
import mlflow
# Step 1: Set up the MLflow tracking server
mlflow.set_tracking_uri("http://ec2-100-26-35-174.compute-1.amazonaws.com:5000/")

# %%
# Set or create an experiment
mlflow.set_experiment("Exp_5 - ML Algos with HP Tuning")
# Out:
# 2026/07/11 14:06:08 INFO mlflow.tracking.fluent: Experiment with name 'Exp_5 - ML Algos with HP Tuning' does not exist. Creating a new experiment.
# <Experiment: artifact_location='s3://mlops-bucket-jvm/7', creation_time=1783758969395, experiment_id='7', last_update_time=1783758969395, lifecycle_stage='active', name='Exp_5 - ML Algos with HP Tuning', tags={}>

# %%
import optuna
import mlflow
import mlflow.sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('artifacts/youtube_preprocessing.csv').dropna()
df.shape
# Out:
# (36662, 2)

# %%
# Step 1: Remap the class labels from [-1, 0, 1] to [2, 0, 1]
df['category'] = df['category'].map({-1: 2, 0: 0, 1: 1})

# Step 2: Remove rows where the target labels (category) are NaN
df = df.dropna(subset=['category'])

ngram_range = (1, 3)  # Trigram setting
max_features = 10000  # Set max_features to 1000 for TF-IDF

# Step 4: Train-test split before vectorization and resampling
X_train, X_test, y_train, y_test = train_test_split(df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category'])

# Step 2: Vectorization using TF-IDF, fit on training data only
vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=max_features)
X_train_vec = vectorizer.fit_transform(X_train)  # Fit on training data
X_test_vec = vectorizer.transform(X_test)  # Transform test data

smote = SMOTE(random_state=42)
X_train_vec, y_train = smote.fit_resample(X_train_vec, y_train)

# Function to log results in MLflow
def log_mlflow(model_name, model, X_train, X_test, y_train, y_test):
    with mlflow.start_run():
        # Log model type
        mlflow.set_tag("mlflow.runName", f"{model_name}_SMOTE_TFIDF_Trigrams")
        mlflow.set_tag("experiment_type", "algorithm_comparison")

        # Log algorithm name as a parameter
        mlflow.log_param("algo_name", model_name)

        # Train model
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log the model
        mlflow.sklearn.log_model(model, f"{model_name}_model")


# Step 6: Optuna objective function for XGBoost
def objective_xgboost(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True)
    max_depth = trial.suggest_int('max_depth', 3, 10)

    model = XGBClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth, random_state=42)
    return accuracy_score(y_test, model.fit(X_train_vec, y_train).predict(X_test_vec))


# Step 7: Run Optuna for XGBoost, log the best model only
def run_optuna_experiment():
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_xgboost, n_trials=30)

    # Get the best parameters and log only the best model
    best_params = study.best_params
    best_model = XGBClassifier(n_estimators=best_params['n_estimators'], learning_rate=best_params['learning_rate'], max_depth=best_params['max_depth'], random_state=42)

    # Log the best model with MLflow, passing the algo_name as "xgboost"
    log_mlflow("XGBoost", best_model, X_train_vec, X_test_vec, y_train, y_test)

# Run the experiment for XGBoost
run_optuna_experiment()
# Out:
# [I 2026-07-11 14:06:35,795] A new study created in memory with name: no-name-1f53fdb6-1490-421c-bce3-1901621f0b18
# [I 2026-07-11 14:07:06,201] Trial 0 finished with value: 0.5303422882858312 and parameters: {'n_estimators': 226, 'learning_rate': 0.0005051473816686175, 'max_depth': 3}. Best is trial 0 with value: 0.5303422882858312.
# [I 2026-07-11 14:08:36,075] Trial 1 finished with value: 0.5606163916541661 and parameters: {'n_estimators': 241, 'learning_rate': 0.0010668119525444242, 'max_depth': 5}. Best is trial 1 with value: 0.5606163916541661.
# [I 2026-07-11 14:09:11,507] Trial 2 finished with value: 0.7396699849993181 and parameters: {'n_estimators': 171, 'learning_rate': 0.0919442578853375, 'max_depth': 4}. Best is trial 2 with value: 0.7396699849993181.
# [I 2026-07-11 14:09:34,091] Trial 3 finished with value: 0.7028501295513433 and parameters: {'n_estimators': 101, 'learning_rate': 0.07918249115390545, 'max_depth': 4}. Best is trial 2 with value: 0.7396699849993181.
# [I 2026-07-11 14:15:08,847] Trial 4 finished with value: 0.6120278194463384 and parameters: {'n_estimators': 235, 'learning_rate': 0.0001274891456983505, 'max_depth': 10}. Best is trial 2 with value: 0.7396699849993181.
# [I 2026-07-11 14:15:21,565] Trial 5 finished with value: 0.602618300831856 and parameters: {'n_estimators': 88, 'learning_rate': 0.025275416950096337, 'max_depth': 3}. Best is trial 2 with value: 0.7396699849993181.
# [I 2026-07-11 14:16:30,947] Trial 6 finished with value: 0.5460248193099686 and parameters: {'n_estimators': 188, 'learning_rate': 0.00030270710627589725, 'max_depth': 5}. Best is trial 2 with value: 0.7396699849993181.
# [I 2026-07-11 14:18:22,793] Trial 7 finished with value: 0.6718941770080458 and parameters: {'n_estimators': 212, 'learning_rate': 0.014805675845568045, 'max_depth': 6}. Best is trial 2 with value: 0.7396699849993181.
# [I 2026-07-11 14:18:34,436] Trial 8 finished with value: 0.5765716623482886 and parameters: {'n_estimators': 80, 'learning_rate': 0.014603500557078042, 'max_depth': 3}. Best is trial 2 with value: 0.7396699849993181.
# [I 2026-07-11 14:19:06,291] Trial 9 finished with value: 0.6716214373380608 and parameters: {'n_estimators': 59, 'learning_rate': 0.05260360902614978, 'max_depth': 6}. Best is trial 2 with value: 0.7396699849993181.
# [I 2026-07-11 14:22:10,175] Trial 10 finished with value: 0.6200736397108959 and parameters: {'n_estimators': 157, 'learning_rate': 0.002246540912390723, 'max_depth': 9}. Best is trial 2 with value: 0.7396699849993181.
# [I 2026-07-11 14:23:31,796] Trial 11 finished with value: 0.7876721669166781 and parameters: {'n_estimators': 298, 'learning_rate': 0.09547792426414971, 'max_depth': 5}. Best is trial 11 with value: 0.7876721669166781.
# [I 2026-07-11 14:25:44,520] Trial 12 finished with value: 0.803763807445793 and parameters: {'n_estimators': 290, 'learning_rate': 0.09245161287705676, 'max_depth': 7}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:30:37,956] Trial 13 finished with value: 0.6555297968089459 and parameters: {'n_estimators': 298, 'learning_rate': 0.005010943503342342, 'max_depth': 8}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:33:32,448] Trial 14 finished with value: 0.7471703259239056 and parameters: {'n_estimators': 300, 'learning_rate': 0.03331867881492405, 'max_depth': 7}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:36:52,526] Trial 15 finished with value: 0.6553934269739533 and parameters: {'n_estimators': 268, 'learning_rate': 0.006871214643624266, 'max_depth': 7}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:40:01,421] Trial 16 finished with value: 0.7546706668484932 and parameters: {'n_estimators': 264, 'learning_rate': 0.03760091005758488, 'max_depth': 8}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:41:44,190] Trial 17 finished with value: 0.790945042956498 and parameters: {'n_estimators': 272, 'learning_rate': 0.09457476037880218, 'max_depth': 6}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:44:44,496] Trial 18 finished with value: 0.6998499931815082 and parameters: {'n_estimators': 265, 'learning_rate': 0.016774441445315483, 'max_depth': 7}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:46:53,735] Trial 19 finished with value: 0.6383471975998909 and parameters: {'n_estimators': 137, 'learning_rate': 0.006591269530325935, 'max_depth': 8}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:48:47,852] Trial 20 finished with value: 0.7471703259239056 and parameters: {'n_estimators': 269, 'learning_rate': 0.04398390402948394, 'max_depth': 6}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:50:06,764] Trial 21 finished with value: 0.785762989226783 and parameters: {'n_estimators': 286, 'learning_rate': 0.09592677626491532, 'max_depth': 5}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:51:48,292] Trial 22 finished with value: 0.7584890222282831 and parameters: {'n_estimators': 247, 'learning_rate': 0.058577998946460035, 'max_depth': 6}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:52:49,541] Trial 23 finished with value: 0.6881221873721532 and parameters: {'n_estimators': 276, 'learning_rate': 0.02492283223829789, 'max_depth': 4}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:54:48,075] Trial 24 finished with value: 0.8000818219009955 and parameters: {'n_estimators': 252, 'learning_rate': 0.09622066742082973, 'max_depth': 7}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 14:56:46,963] Trial 25 finished with value: 0.7534433383335606 and parameters: {'n_estimators': 211, 'learning_rate': 0.05267171637320267, 'max_depth': 7}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 15:00:58,497] Trial 26 finished with value: 0.7309423155597982 and parameters: {'n_estimators': 252, 'learning_rate': 0.0225912818221153, 'max_depth': 9}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 15:04:21,418] Trial 27 finished with value: 0.6735306150279559 and parameters: {'n_estimators': 217, 'learning_rate': 0.010370319918140003, 'max_depth': 8}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 15:06:35,667] Trial 28 finished with value: 0.7654438838129006 and parameters: {'n_estimators': 251, 'learning_rate': 0.05337129119139831, 'max_depth': 7}. Best is trial 12 with value: 0.803763807445793.
# [I 2026-07-11 15:10:01,578] Trial 29 finished with value: 0.7310786853947907 and parameters: {'n_estimators': 194, 'learning_rate': 0.029514904902834996, 'max_depth': 9}. Best is trial 12 with value: 0.803763807445793.
# 2026/07/11 15:12:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026/07/11 15:12:50 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_SMOTE_TFIDF_Trigrams at: http://ec2-100-26-35-174.compute-1.amazonaws.com:5000/#/experiments/7/runs/236593366a3b4902bd7932731843ef87.
# 2026/07/11 15:12:50 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-100-26-35-174.compute-1.amazonaws.com:5000/#/experiments/7.
